# %% [markdown]
# <a href="https://colab.research.google.com/github/TheS1n233/Distributed-Learning-Project5/blob/test/YUJIE-Centralized%20baseline-SGDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # install torch and torchvision

# %%
# !pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# # install dataset CIFAR-100

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import time
from PIL import Image

# Data preprocessing
class Cutout(object):
    def __init__(self, size):
        self.size = size

    def __call__(self, img):
        # 如果 img 是 PIL.Image，则先转换为 NumPy 数组
        if isinstance(img, Image.Image):
            img = np.array(img)

        h, w = img.shape[:2]
        mask = np.ones((h, w), np.float32)
        y = np.random.randint(h)
        x = np.random.randint(w)
        y1 = np.clip(y - self.size // 2, 0, h)
        y2 = np.clip(y + self.size // 2, 0, h)
        x1 = np.clip(x - self.size // 2, 0, w)
        x2 = np.clip(x + self.size // 2, 0, w)
        mask[y1: y2, x1: x2] = 0
        img = img * mask[:, :, np.newaxis]  # Apply a mask to the RGB channel
        return Image.fromarray(np.uint8(img))

# Data transformations
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    Cutout(size=8),  # Add Cutout
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Download CIFAR-100 dataset
start_time = time.time()
train_dataset = torchvision.datasets.CIFAR100(
    root='./data',
    train=True,
    download=True,
    transform=transform_train
)
test_dataset = torchvision.datasets.CIFAR100(
    root='./data',
    train=False,
    download=True,
    transform=transform_test
)
print(f"Dataset loading time: {time.time() - start_time:.2f} seconds")

# Split training and validation sets
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

# Create data loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=128,  # Updated batch size
    shuffle=True,
    num_workers=2,
    pin_memory=True  # Enable prefetching
)
val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

# Test data loading performance
data_start = time.time()
for i, (inputs, labels) in enumerate(train_loader):
    if i == 10:  # Test first 10 batches
        break
print(f"Data loading for 10 batches: {time.time() - data_start:.2f} seconds")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 35.0MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Dataset loading time: 9.00 seconds
# Data loading for 10 batches: 2.07 seconds

# %% [markdown]
# # Define LeNet-5

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import random
import numpy as np
import json
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
class LeNet5(nn.Module):
    def __init__(self, use_batch_norm=True, dropout1=0.3, dropout2=0.3):
        super(LeNet5, self).__init__()
        self.use_batch_norm = use_batch_norm

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32) if self.use_batch_norm else None

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64) if self.use_batch_norm else None

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128) if self.use_batch_norm else None

        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.dropout1 = nn.Dropout(p=dropout1)
        self.fc2 = nn.Linear(512, 1024)
        self.dropout2 = nn.Dropout(p=dropout2)
        self.fc3 = nn.Linear(1024, 100)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)) if self.bn1 else self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn2(self.conv2(x)) if self.bn2 else self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn3(self.conv3(x)) if self.bn3 else self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# # Hyperparameters choosing by SGDM

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import random
import numpy as np
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
import matplotlib.pyplot as plt
import time
from torch.amp import GradScaler, autocast
import json
import os
from google.colab import drive
drive.mount('/content/drive')
if not os.path.exists('/content/drive/MyDrive'):
    raise RuntimeError("Google Drive not mounted correctly!")

# Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=10, delta=0, path='/content/drive/MyDrive/Early1checkpoint.pt', verbose=False):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path
        self.verbose = verbose

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f"Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...")
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss


# Random search
def random_search(train_loader, val_loader, model_class, device, num_trials):
    param_space = {
        'lr': [0.08, 0.09, 0.1, 0.11, 0.12],
        'weight_decay': [1e-6, 1e-5, 5e-5],
        'momentum': [0.85, 0.88, 0.9],
        'dropout1': [0.2, 0.3, 0.35],
        'dropout2': [0.15, 0.2, 0.3],
    }

    results = []

    for trial in range(num_trials):
        print(f"Trial {trial + 1}/{num_trials}")
        lr = random.choice(param_space['lr'])
        weight_decay = random.choice(param_space['weight_decay'])
        momentum = random.choice(param_space['momentum'])
        dropout1 = random.choice(param_space['dropout1'])
        dropout2 = random.choice(param_space['dropout2'])

        model = model_class().to(device)
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
        scheduler = CosineAnnealingLR(optimizer, T_max=5)
        criterion = nn.CrossEntropyLoss()
        early_stopping = EarlyStopping(verbose=True)

        train_loss, val_loss, val_acc = train_and_evaluate(
            model, optimizer, scheduler, criterion, train_loader, val_loader, num_epochs=5, device=device, early_stopping=early_stopping
        )

        results.append({
            'lr': lr,
            'weight_decay': weight_decay,
            'momentum': momentum,
            'dropout1': dropout1,
            'dropout2': dropout2,
            'val_loss': val_loss,
            'val_acc': val_acc
        })

        if early_stopping.early_stop:
            print("Early stopping triggered.")
            break

    results.sort(key=lambda x: x['val_acc'], reverse=True)
    best_hyperparams = results[0]

    with open('/content/drive/MyDrive/best_hyperparams_SGDM.json', 'w') as f:
        json.dump(best_hyperparams, f)
    print("\nBest Hyperparameters saved to /content/drive/MyDrive/best_hyperparams_SGDM.json")

    return best_hyperparams


# Training and evaluation function with early stopping
def train_and_evaluate(model, optimizer, scheduler, criterion, train_loader, val_loader, num_epochs, device, early_stopping):
    model.train()
    scaler = GradScaler(device='cuda')  # Initialize mixed precision scaler

    for epoch in range(num_epochs):
        epoch_start = time.time()

        # Training loop
        train_loss_total = 0
        train_correct, train_total = 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            optimizer.zero_grad()

            with autocast(device_type='cuda'):  # Mixed precision forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            train_loss_total += loss.item()
            _, predicted = outputs.max(1)
            train_total += labels.size(0)
            train_correct += predicted.eq(labels).sum().item()

        train_loss = train_loss_total / len(train_loader)
        train_acc = 100. * train_correct / train_total

        # Validation loop
        model.eval()
        val_loss, correct, total = 0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
                with autocast(device_type='cuda'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

        val_acc = 100. * correct / total
        val_loss /= len(val_loader)

        epoch_end = time.time()
        print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%")

        scheduler.step()

        # Early stopping
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping at epoch:", epoch + 1)
            break

    return train_loss, val_loss, val_acc


# Main function
if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    best_hyperparams = random_search(
        train_loader=train_loader,
        val_loader=val_loader,
        model_class=LeNet5,
        device=device,
        num_trials=10
    )

    print("\nUsing Best Hyperparameters:")
    print(best_hyperparams)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Trial 1/10
# Epoch 1/5 | Train Loss: 4.2696 | Train Acc: 4.67% | Val Loss: 4.0731 | Val Acc: 6.95%
# Validation loss decreased (inf --> 4.073081).  Saving model ...
# Epoch 2/5 | Train Loss: 3.8906 | Train Acc: 9.60% | Val Loss: 3.6902 | Val Acc: 13.00%
# Validation loss decreased (4.073081 --> 3.690163).  Saving model ...
# Epoch 3/5 | Train Loss: 3.5845 | Train Acc: 14.46% | Val Loss: 3.5367 | Val Acc: 15.85%
# Validation loss decreased (3.690163 --> 3.536707).  Saving model ...
# Epoch 4/5 | Train Loss: 3.3156 | Train Acc: 19.32% | Val Loss: 3.3046 | Val Acc: 20.05%
# Validation loss decreased (3.536707 --> 3.304573).  Saving model ...
# Epoch 5/5 | Train Loss: 3.0852 | Train Acc: 23.70% | Val Loss: 3.1566 | Val Acc: 23.11%
# Validation loss decreased (3.304573 --> 3.156594).  Saving model ...
# Trial 2/10
# Epoch 1/5 | Train Loss: 4.2547 | Train Acc: 4.96% | Val Loss: 4.0146 | Val Acc: 7.53%
# Validation loss decreased (inf --> 4.014613).  Saving model ...
# Epoch 2/5 | Train Loss: 3.8711 | Train Acc: 10.16% | Val Loss: 3.7365 | Val Acc: 12.31%
# Validation loss decreased (4.014613 --> 3.736535).  Saving model ...
# Epoch 3/5 | Train Loss: 3.5712 | Train Acc: 14.86% | Val Loss: 3.4794 | Val Acc: 16.69%
# Validation loss decreased (3.736535 --> 3.479392).  Saving model ...
# Epoch 4/5 | Train Loss: 3.2974 | Train Acc: 19.48% | Val Loss: 3.2524 | Val Acc: 20.66%
# Validation loss decreased (3.479392 --> 3.252408).  Saving model ...
# Epoch 5/5 | Train Loss: 3.0751 | Train Acc: 23.66% | Val Loss: 3.1043 | Val Acc: 24.00%
# Validation loss decreased (3.252408 --> 3.104288).  Saving model ...
# Trial 3/10
# Epoch 1/5 | Train Loss: 4.2238 | Train Acc: 5.14% | Val Loss: 3.9690 | Val Acc: 8.26%
# Validation loss decreased (inf --> 3.969044).  Saving model ...
# Epoch 2/5 | Train Loss: 3.9257 | Train Acc: 9.11% | Val Loss: 3.8627 | Val Acc: 11.01%
# Validation loss decreased (3.969044 --> 3.862669).  Saving model ...
# Epoch 3/5 | Train Loss: 3.5691 | Train Acc: 14.68% | Val Loss: 3.4388 | Val Acc: 17.67%
# Validation loss decreased (3.862669 --> 3.438803).  Saving model ...
# Epoch 4/5 | Train Loss: 3.3130 | Train Acc: 19.35% | Val Loss: 3.3256 | Val Acc: 19.71%
# Validation loss decreased (3.438803 --> 3.325606).  Saving model ...
# Epoch 5/5 | Train Loss: 3.0971 | Train Acc: 23.10% | Val Loss: 3.1005 | Val Acc: 23.40%
# Validation loss decreased (3.325606 --> 3.100462).  Saving model ...
# Trial 4/10
# Epoch 1/5 | Train Loss: 4.2358 | Train Acc: 4.89% | Val Loss: 4.0703 | Val Acc: 7.38%
# Validation loss decreased (inf --> 4.070350).  Saving model ...
# Epoch 2/5 | Train Loss: 3.8763 | Train Acc: 9.80% | Val Loss: 3.7101 | Val Acc: 12.17%
# Validation loss decreased (4.070350 --> 3.710074).  Saving model ...
# Epoch 3/5 | Train Loss: 3.5614 | Train Acc: 14.69% | Val Loss: 3.4678 | Val Acc: 16.86%
# Validation loss decreased (3.710074 --> 3.467758).  Saving model ...
# Epoch 4/5 | Train Loss: 3.2895 | Train Acc: 19.52% | Val Loss: 3.2866 | Val Acc: 20.18%
# Validation loss decreased (3.467758 --> 3.286624).  Saving model ...
# Epoch 5/5 | Train Loss: 3.0619 | Train Acc: 23.88% | Val Loss: 3.0849 | Val Acc: 23.60%
# Validation loss decreased (3.286624 --> 3.084867).  Saving model ...
# Trial 5/10
# Epoch 1/5 | Train Loss: 4.2933 | Train Acc: 4.41% | Val Loss: 4.1552 | Val Acc: 6.03%
# Validation loss decreased (inf --> 4.155162).  Saving model ...
# Epoch 2/5 | Train Loss: 3.9396 | Train Acc: 8.74% | Val Loss: 3.7817 | Val Acc: 11.51%
# Validation loss decreased (4.155162 --> 3.781750).  Saving model ...
# Epoch 3/5 | Train Loss: 3.6381 | Train Acc: 13.63% | Val Loss: 3.5588 | Val Acc: 15.36%
# Validation loss decreased (3.781750 --> 3.558774).  Saving model ...
# Epoch 4/5 | Train Loss: 3.3639 | Train Acc: 18.18% | Val Loss: 3.3123 | Val Acc: 19.41%
# Validation loss decreased (3.558774 --> 3.312251).  Saving model ...
# Epoch 5/5 | Train Loss: 3.1449 | Train Acc: 22.33% | Val Loss: 3.1549 | Val Acc: 22.82%
# Validation loss decreased (3.312251 --> 3.154896).  Saving model ...
# Trial 6/10
# Epoch 1/5 | Train Loss: 4.2778 | Train Acc: 4.72% | Val Loss: 3.9994 | Val Acc: 7.98%
# Validation loss decreased (inf --> 3.999399).  Saving model ...
# Epoch 2/5 | Train Loss: 3.9347 | Train Acc: 8.79% | Val Loss: 3.7619 | Val Acc: 12.16%
# Validation loss decreased (3.999399 --> 3.761937).  Saving model ...
# Epoch 3/5 | Train Loss: 3.6197 | Train Acc: 14.03% | Val Loss: 3.5906 | Val Acc: 15.06%
# Validation loss decreased (3.761937 --> 3.590556).  Saving model ...
# Epoch 4/5 | Train Loss: 3.3500 | Train Acc: 18.60% | Val Loss: 3.3075 | Val Acc: 20.06%
# Validation loss decreased (3.590556 --> 3.307460).  Saving model ...
# Epoch 5/5 | Train Loss: 3.1124 | Train Acc: 22.93% | Val Loss: 3.1272 | Val Acc: 23.37%
# Validation loss decreased (3.307460 --> 3.127245).  Saving model ...
# Trial 7/10
# Epoch 1/5 | Train Loss: 4.2773 | Train Acc: 4.49% | Val Loss: 4.0377 | Val Acc: 7.24%
# Validation loss decreased (inf --> 4.037650).  Saving model ...
# Epoch 2/5 | Train Loss: 3.8950 | Train Acc: 9.55% | Val Loss: 3.7409 | Val Acc: 12.27%
# Validation loss decreased (4.037650 --> 3.740899).  Saving model ...
# Epoch 3/5 | Train Loss: 3.5827 | Train Acc: 14.57% | Val Loss: 3.5355 | Val Acc: 15.77%
# Validation loss decreased (3.740899 --> 3.535541).  Saving model ...
# Epoch 4/5 | Train Loss: 3.3082 | Train Acc: 19.54% | Val Loss: 3.2668 | Val Acc: 20.61%
# Validation loss decreased (3.535541 --> 3.266757).  Saving model ...
# Epoch 5/5 | Train Loss: 3.0852 | Train Acc: 23.58% | Val Loss: 3.1182 | Val Acc: 23.85%
# Validation loss decreased (3.266757 --> 3.118182).  Saving model ...
# Trial 8/10
# Epoch 1/5 | Train Loss: 4.3197 | Train Acc: 3.96% | Val Loss: 4.1424 | Val Acc: 6.05%
# Validation loss decreased (inf --> 4.142420).  Saving model ...
# Epoch 2/5 | Train Loss: 3.9661 | Train Acc: 8.26% | Val Loss: 3.8851 | Val Acc: 10.04%
# Validation loss decreased (4.142420 --> 3.885122).  Saving model ...
# Epoch 3/5 | Train Loss: 3.6901 | Train Acc: 12.52% | Val Loss: 3.6104 | Val Acc: 13.59%
# Validation loss decreased (3.885122 --> 3.610356).  Saving model ...
# Epoch 4/5 | Train Loss: 3.4239 | Train Acc: 17.10% | Val Loss: 3.4011 | Val Acc: 17.97%
# Validation loss decreased (3.610356 --> 3.401105).  Saving model ...
# Epoch 5/5 | Train Loss: 3.1995 | Train Acc: 21.44% | Val Loss: 3.1987 | Val Acc: 21.27%
# Validation loss decreased (3.401105 --> 3.198729).  Saving model ...
# Trial 9/10
# Epoch 1/5 | Train Loss: 4.2261 | Train Acc: 4.95% | Val Loss: 4.0763 | Val Acc: 7.32%
# Validation loss decreased (inf --> 4.076264).  Saving model ...
# Epoch 2/5 | Train Loss: 3.8442 | Train Acc: 10.27% | Val Loss: 3.7648 | Val Acc: 11.37%
# Validation loss decreased (4.076264 --> 3.764782).  Saving model ...
# Epoch 3/5 | Train Loss: 3.5217 | Train Acc: 15.70% | Val Loss: 3.4260 | Val Acc: 18.15%
# Validation loss decreased (3.764782 --> 3.426010).  Saving model ...
# Epoch 4/5 | Train Loss: 3.2512 | Train Acc: 20.25% | Val Loss: 3.2126 | Val Acc: 22.01%
# Validation loss decreased (3.426010 --> 3.212599).  Saving model ...
# Epoch 5/5 | Train Loss: 3.0171 | Train Acc: 24.89% | Val Loss: 3.0455 | Val Acc: 25.02%
# Validation loss decreased (3.212599 --> 3.045509).  Saving model ...
# Trial 10/10
# Epoch 1/5 | Train Loss: 4.3135 | Train Acc: 4.13% | Val Loss: 4.0864 | Val Acc: 6.86%
# Validation loss decreased (inf --> 4.086439).  Saving model ...
# Epoch 2/5 | Train Loss: 3.9318 | Train Acc: 8.99% | Val Loss: 3.8007 | Val Acc: 11.55%
# Validation loss decreased (4.086439 --> 3.800673).  Saving model ...
# Epoch 3/5 | Train Loss: 3.6390 | Train Acc: 13.89% | Val Loss: 3.5326 | Val Acc: 15.39%
# Validation loss decreased (3.800673 --> 3.532614).  Saving model ...
# Epoch 4/5 | Train Loss: 3.3666 | Train Acc: 18.02% | Val Loss: 3.3078 | Val Acc: 19.61%
# Validation loss decreased (3.532614 --> 3.307780).  Saving model ...
# Epoch 5/5 | Train Loss: 3.1388 | Train Acc: 22.26% | Val Loss: 3.1620 | Val Acc: 22.28%
# Validation loss decreased (3.307780 --> 3.162004).  Saving model ...
#
# Best Hyperparameters saved to /content/drive/MyDrive/best_hyperparams_SGDM.json
#
# Using Best Hyperparameters:
# {'lr': 0.09, 'weight_decay': 1e-06, 'momentum': 0.85, 'dropout1': 0.3, 'dropout2': 0.2, 'val_loss': 3.045509268965902, 'val_acc': 25.02}

# %% [markdown]
# # Centralized baseline with SGDM

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import random
import numpy as np
import json
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
import matplotlib.pyplot as plt
import time
from torch.amp import GradScaler, autocast
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
if not os.path.exists('/content/drive/MyDrive'):
    raise RuntimeError("Google Drive not mounted correctly!")

# Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=10, delta=0, path='/content/drive/MyDrive/Early2checkpoint.pt', verbose=False):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path
        self.verbose = verbose

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)

        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, optimizer=None):
        if self.verbose:
            print(f"Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model ...")
        checkpoint = {
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict() if optimizer else None,
            'val_loss_min': val_loss
        }
        torch.save(checkpoint, self.path)
        self.val_loss_min = val_loss





# Centralized baseline training function with checkpoints
def train_model_with_hyperparams(train_loader, val_loader, test_loader, best_hyperparams, num_epochs, device, checkpoint_path, use_batch_norm=True):
    model = LeNet5(use_batch_norm=use_batch_norm,).to(device)
    optimizer = optim.SGD(
        model.parameters(),
        lr=best_hyperparams['lr'],
        momentum=best_hyperparams['momentum'],
        weight_decay=best_hyperparams['weight_decay']
    )
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
    criterion = nn.CrossEntropyLoss()
    early_stopping = EarlyStopping(patience=best_hyperparams.get('patience', 10), verbose=True)

    # Checkpoint recovery
    start_epoch = 0
    if os.path.exists(checkpoint_path):
        print(f"Checkpoint found at {checkpoint_path}. Loading model state...")
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        start_epoch = checkpoint['epoch']
        print(f"Resuming training from epoch {start_epoch + 1}")
    else:
        print(f"No checkpoint found at {checkpoint_path}. Training a new model from scratch.")
        checkpoint = None


    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
    scaler = GradScaler()

    for epoch in range(start_epoch, num_epochs):
        model.train()
        train_loss_total, train_correct, train_total = 0, 0, 0

        # Training loop
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            optimizer.zero_grad()
            with autocast(device_type=device.type):
                outputs = model(inputs)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            train_loss_total += loss.item()
            _, predicted = outputs.max(1)
            train_total += labels.size(0)
            train_correct += predicted.eq(labels).sum().item()

        train_loss = train_loss_total / len(train_loader)
        train_acc = 100. * train_correct / train_total
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # Validation loop
        model.eval()
        val_loss_total, val_correct, val_total = 0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)

                with autocast(device_type=device.type):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                val_loss_total += loss.item()
                _, predicted = outputs.max(1)
                val_total += labels.size(0)
                val_correct += predicted.eq(labels).sum().item()

        val_loss = val_loss_total / len(val_loader)
        val_acc = 100. * val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        print(f"Epoch {epoch + 1}/{num_epochs} | Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

        scheduler.step()
        early_stopping(val_loss, model)

        # Save checkpoint
        checkpoint = {
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'train_losses': train_losses,
            'val_losses': val_losses,
            'train_accuracies': train_accuracies,
            'val_accuracies': val_accuracies
        }
        torch.save(checkpoint, '/content/drive/MyDrive/CentralizedCheckpoint.pth')
        print(f"Checkpoint saved to Google Drive at epoch {epoch + 1}")

        if early_stopping.early_stop:
            print(f"Early stopping at epoch {epoch + 1}")
            break

    # Load the best model
    checkpoint = torch.load('/content/drive/MyDrive/Early2checkpoint.pt')
    model.load_state_dict(checkpoint['model_state_dict'])

    # Test loop
    model.eval()
    test_correct, test_total = 0, 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)

            with autocast(device_type=device.type):
                outputs = model(inputs)

            _, predicted = outputs.max(1)
            test_total += labels.size(0)
            test_correct += predicted.eq(labels).sum().item()

    test_acc = 100. * test_correct / test_total
    print(f"Final Test Accuracy: {test_acc:.2f}%")
    return train_losses, val_losses, train_accuracies, val_accuracies, test_acc

# Main function
if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Use the best hyperparameters from random search
    with open('/content/drive/MyDrive/best_hyperparams_SGDM.json', 'r') as f:
        best_hyperparams = json.load(f)

    print("\nUsing Best Hyperparameters from Random Search:", best_hyperparams)

    # Train with the best hyperparameters
    train_losses, val_losses, train_accuracies, val_accuracies, test_acc = train_model_with_hyperparams(
        train_loader=train_loader,
        val_loader=val_loader,
        test_loader=test_loader,
        best_hyperparams=best_hyperparams,
        num_epochs=150,
        device=device,
        checkpoint_path='/content/drive/MyDrive/checkpoint1.pth'
    )

    # Plot results
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(12, 5))

    # Plot losses
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot accuracies
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.tight_layout()

    # Save the plot before showing it
    save_path = '/content/drive/My Drive/Colab Notebooks/Traning_summary/Traning2'
    plt.savefig(save_path + 'training_results.png')
    print("Training results saved to Google Drive as 'training_results.png'")

    plt.show()

    # Save the summary
    with open(save_path + 'training_summary.txt', 'w') as f:
        f.write(f"Final Test Accuracy: {test_acc:.2f}%\n")
        f.write("Training and Validation Results:\n")
        f.write(f"Train Losses: {train_losses}\n")
        f.write(f"Validation Losses: {val_losses}\n")
        f.write(f"Train Accuracies: {train_accuracies}\n")
        f.write(f"Validation Accuracies: {val_accuracies}\n")
    print("Training summary saved to Google Drive as 'training_summary.txt'")
# Out:
# Mounted at /content/drive
#
# Using Best Hyperparameters from Random Search: {'lr': 0.09, 'weight_decay': 1e-06, 'momentum': 0.85, 'dropout1': 0.3, 'dropout2': 0.2, 'val_loss': 3.045509268965902, 'val_acc': 25.02}
# No checkpoint found at /content/drive/MyDrive/checkpoint1.pth. Training a new model from scratch.
# Epoch 1/150 | Train Loss: 4.2440, Train Acc: 4.95% | Val Loss: 4.0964, Val Acc: 7.37%
# Validation loss decreased (inf --> 4.096445). Saving model ...
# Checkpoint saved to Google Drive at epoch 1
# Epoch 2/150 | Train Loss: 3.9660, Train Acc: 8.04% | Val Loss: 3.8766, Val Acc: 10.12%
# Validation loss decreased (4.096445 --> 3.876640). Saving model ...
# Checkpoint saved to Google Drive at epoch 2
# Epoch 3/150 | Train Loss: 3.7814, Train Acc: 10.98% | Val Loss: 3.6223, Val Acc: 14.50%
# Validation loss decreased (3.876640 --> 3.622268). Saving model ...
# Checkpoint saved to Google Drive at epoch 3
# Epoch 4/150 | Train Loss: 3.6125, Train Acc: 13.47% | Val Loss: 3.4496, Val Acc: 16.77%
# Validation loss decreased (3.622268 --> 3.449630). Saving model ...
# Checkpoint saved to Google Drive at epoch 4
# Epoch 5/150 | Train Loss: 3.4691, Train Acc: 16.36% | Val Loss: 3.3437, Val Acc: 18.52%
# Validation loss decreased (3.449630 --> 3.343706). Saving model ...
# Checkpoint saved to Google Drive at epoch 5
# Epoch 6/150 | Train Loss: 3.3480, Train Acc: 18.21% | Val Loss: 3.3055, Val Acc: 19.96%
# Validation loss decreased (3.343706 --> 3.305505). Saving model ...
# Checkpoint saved to Google Drive at epoch 6
# Epoch 7/150 | Train Loss: 3.2296, Train Acc: 20.66% | Val Loss: 3.1579, Val Acc: 22.66%
# Validation loss decreased (3.305505 --> 3.157926). Saving model ...
# Checkpoint saved to Google Drive at epoch 7
# Epoch 8/150 | Train Loss: 3.1357, Train Acc: 22.56% | Val Loss: 3.1770, Val Acc: 22.54%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 8
# Epoch 9/150 | Train Loss: 3.0496, Train Acc: 23.86% | Val Loss: 2.9772, Val Acc: 25.22%
# Validation loss decreased (3.157926 --> 2.977237). Saving model ...
# Checkpoint saved to Google Drive at epoch 9
# Epoch 10/150 | Train Loss: 2.9782, Train Acc: 25.52% | Val Loss: 2.9103, Val Acc: 27.21%
# Validation loss decreased (2.977237 --> 2.910325). Saving model ...
# Checkpoint saved to Google Drive at epoch 10
# Epoch 11/150 | Train Loss: 2.9081, Train Acc: 27.02% | Val Loss: 2.8814, Val Acc: 27.94%
# Validation loss decreased (2.910325 --> 2.881400). Saving model ...
# Checkpoint saved to Google Drive at epoch 11
# Epoch 12/150 | Train Loss: 2.8631, Train Acc: 27.85% | Val Loss: 2.7292, Val Acc: 30.99%
# Validation loss decreased (2.881400 --> 2.729240). Saving model ...
# Checkpoint saved to Google Drive at epoch 12
# Epoch 13/150 | Train Loss: 2.8024, Train Acc: 29.23% | Val Loss: 2.7199, Val Acc: 31.66%
# Validation loss decreased (2.729240 --> 2.719893). Saving model ...
# Checkpoint saved to Google Drive at epoch 13
# Epoch 14/150 | Train Loss: 2.7611, Train Acc: 29.78% | Val Loss: 2.7401, Val Acc: 31.15%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 14
# Epoch 15/150 | Train Loss: 2.7161, Train Acc: 30.88% | Val Loss: 2.7020, Val Acc: 31.84%
# Validation loss decreased (2.719893 --> 2.701964). Saving model ...
# Checkpoint saved to Google Drive at epoch 15
# Epoch 16/150 | Train Loss: 2.6804, Train Acc: 31.73% | Val Loss: 2.7148, Val Acc: 31.60%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 16
# Epoch 17/150 | Train Loss: 2.6534, Train Acc: 32.03% | Val Loss: 2.6642, Val Acc: 32.21%
# Validation loss decreased (2.701964 --> 2.664159). Saving model ...
# Checkpoint saved to Google Drive at epoch 17
# Epoch 18/150 | Train Loss: 2.6165, Train Acc: 32.88% | Val Loss: 2.6095, Val Acc: 33.65%
# Validation loss decreased (2.664159 --> 2.609545). Saving model ...
# Checkpoint saved to Google Drive at epoch 18
# Epoch 19/150 | Train Loss: 2.5795, Train Acc: 33.38% | Val Loss: 2.7082, Val Acc: 32.14%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 19
# Epoch 20/150 | Train Loss: 2.5634, Train Acc: 34.29% | Val Loss: 2.5620, Val Acc: 35.15%
# Validation loss decreased (2.609545 --> 2.561968). Saving model ...
# Checkpoint saved to Google Drive at epoch 20
# Epoch 21/150 | Train Loss: 2.5245, Train Acc: 35.17% | Val Loss: 2.5836, Val Acc: 34.46%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 21
# Epoch 22/150 | Train Loss: 2.4965, Train Acc: 35.38% | Val Loss: 2.5058, Val Acc: 35.57%
# Validation loss decreased (2.561968 --> 2.505789). Saving model ...
# Checkpoint saved to Google Drive at epoch 22
# Epoch 23/150 | Train Loss: 2.4876, Train Acc: 35.42% | Val Loss: 2.5282, Val Acc: 36.11%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 23
# Epoch 24/150 | Train Loss: 2.4589, Train Acc: 35.96% | Val Loss: 2.4904, Val Acc: 35.92%
# Validation loss decreased (2.505789 --> 2.490386). Saving model ...
# Checkpoint saved to Google Drive at epoch 24
# Epoch 25/150 | Train Loss: 2.4495, Train Acc: 36.50% | Val Loss: 2.4901, Val Acc: 36.50%
# Validation loss decreased (2.490386 --> 2.490067). Saving model ...
# Checkpoint saved to Google Drive at epoch 25
# Epoch 26/150 | Train Loss: 2.4276, Train Acc: 36.75% | Val Loss: 2.4513, Val Acc: 37.08%
# Validation loss decreased (2.490067 --> 2.451274). Saving model ...
# Checkpoint saved to Google Drive at epoch 26
# Epoch 27/150 | Train Loss: 2.3979, Train Acc: 37.34% | Val Loss: 2.4969, Val Acc: 36.80%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 27
# Epoch 28/150 | Train Loss: 2.3922, Train Acc: 37.95% | Val Loss: 2.4850, Val Acc: 36.27%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 28
# Epoch 29/150 | Train Loss: 2.3631, Train Acc: 38.10% | Val Loss: 2.3998, Val Acc: 38.01%
# Validation loss decreased (2.451274 --> 2.399820). Saving model ...
# Checkpoint saved to Google Drive at epoch 29
# Epoch 30/150 | Train Loss: 2.3582, Train Acc: 38.44% | Val Loss: 2.4234, Val Acc: 37.91%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 30
# Epoch 31/150 | Train Loss: 2.3373, Train Acc: 38.78% | Val Loss: 2.4492, Val Acc: 37.53%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 31
# Epoch 32/150 | Train Loss: 2.3129, Train Acc: 39.34% | Val Loss: 2.3461, Val Acc: 39.26%
# Validation loss decreased (2.399820 --> 2.346054). Saving model ...
# Checkpoint saved to Google Drive at epoch 32
# Epoch 33/150 | Train Loss: 2.2956, Train Acc: 39.72% | Val Loss: 2.3868, Val Acc: 39.02%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 33
# Epoch 34/150 | Train Loss: 2.2832, Train Acc: 40.05% | Val Loss: 2.4422, Val Acc: 38.25%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 34
# Epoch 35/150 | Train Loss: 2.2628, Train Acc: 40.49% | Val Loss: 2.4207, Val Acc: 37.81%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 35
# Epoch 36/150 | Train Loss: 2.2538, Train Acc: 40.57% | Val Loss: 2.3418, Val Acc: 40.11%
# Validation loss decreased (2.346054 --> 2.341843). Saving model ...
# Checkpoint saved to Google Drive at epoch 36
# Epoch 37/150 | Train Loss: 2.2467, Train Acc: 40.84% | Val Loss: 2.4323, Val Acc: 38.01%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 37
# Epoch 38/150 | Train Loss: 2.2214, Train Acc: 41.35% | Val Loss: 2.3377, Val Acc: 39.85%
# Validation loss decreased (2.341843 --> 2.337723). Saving model ...
# Checkpoint saved to Google Drive at epoch 38
# Epoch 39/150 | Train Loss: 2.2155, Train Acc: 41.41% | Val Loss: 2.3343, Val Acc: 40.51%
# Validation loss decreased (2.337723 --> 2.334255). Saving model ...
# Checkpoint saved to Google Drive at epoch 39
# Epoch 40/150 | Train Loss: 2.1866, Train Acc: 41.66% | Val Loss: 2.3843, Val Acc: 38.90%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 40
# Epoch 41/150 | Train Loss: 2.1790, Train Acc: 42.25% | Val Loss: 2.2941, Val Acc: 40.36%
# Validation loss decreased (2.334255 --> 2.294079). Saving model ...
# Checkpoint saved to Google Drive at epoch 41
# Epoch 42/150 | Train Loss: 2.1756, Train Acc: 42.13% | Val Loss: 2.2952, Val Acc: 41.21%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 42
# Epoch 43/150 | Train Loss: 2.1639, Train Acc: 42.66% | Val Loss: 2.3190, Val Acc: 40.69%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 43
# Epoch 44/150 | Train Loss: 2.1518, Train Acc: 42.93% | Val Loss: 2.2479, Val Acc: 41.52%
# Validation loss decreased (2.294079 --> 2.247891). Saving model ...
# Checkpoint saved to Google Drive at epoch 44
# Epoch 45/150 | Train Loss: 2.1404, Train Acc: 43.33% | Val Loss: 2.2675, Val Acc: 41.45%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 45
# Epoch 46/150 | Train Loss: 2.1244, Train Acc: 43.82% | Val Loss: 2.3212, Val Acc: 40.45%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 46
# Epoch 47/150 | Train Loss: 2.1220, Train Acc: 43.51% | Val Loss: 2.2206, Val Acc: 42.38%
# Validation loss decreased (2.247891 --> 2.220597). Saving model ...
# Checkpoint saved to Google Drive at epoch 47
# Epoch 48/150 | Train Loss: 2.0858, Train Acc: 43.98% | Val Loss: 2.2583, Val Acc: 41.68%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 48
# Epoch 49/150 | Train Loss: 2.0768, Train Acc: 44.52% | Val Loss: 2.2373, Val Acc: 41.53%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 49
# Epoch 50/150 | Train Loss: 2.0544, Train Acc: 44.77% | Val Loss: 2.1775, Val Acc: 43.47%
# Validation loss decreased (2.220597 --> 2.177507). Saving model ...
# Checkpoint saved to Google Drive at epoch 50
# Epoch 51/150 | Train Loss: 2.0601, Train Acc: 44.98% | Val Loss: 2.2278, Val Acc: 42.93%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 51
# Epoch 52/150 | Train Loss: 2.0505, Train Acc: 44.85% | Val Loss: 2.2298, Val Acc: 42.42%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 52
# Epoch 53/150 | Train Loss: 2.0287, Train Acc: 45.40% | Val Loss: 2.2448, Val Acc: 42.10%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 53
# Epoch 54/150 | Train Loss: 2.0342, Train Acc: 45.15% | Val Loss: 2.1943, Val Acc: 43.05%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 54
# Epoch 55/150 | Train Loss: 2.0180, Train Acc: 45.66% | Val Loss: 2.2056, Val Acc: 43.27%
# EarlyStopping counter: 5 out of 10
# Checkpoint saved to Google Drive at epoch 55
# Epoch 56/150 | Train Loss: 2.0068, Train Acc: 46.19% | Val Loss: 2.2046, Val Acc: 43.52%
# EarlyStopping counter: 6 out of 10
# Checkpoint saved to Google Drive at epoch 56
# Epoch 57/150 | Train Loss: 1.9908, Train Acc: 46.05% | Val Loss: 2.1818, Val Acc: 43.93%
# EarlyStopping counter: 7 out of 10
# Checkpoint saved to Google Drive at epoch 57
# Epoch 58/150 | Train Loss: 1.9812, Train Acc: 46.62% | Val Loss: 2.2205, Val Acc: 42.45%
# EarlyStopping counter: 8 out of 10
# Checkpoint saved to Google Drive at epoch 58
# Epoch 59/150 | Train Loss: 1.9671, Train Acc: 46.73% | Val Loss: 2.2022, Val Acc: 43.25%
# EarlyStopping counter: 9 out of 10
# Checkpoint saved to Google Drive at epoch 59
# Epoch 60/150 | Train Loss: 1.9490, Train Acc: 47.33% | Val Loss: 2.1715, Val Acc: 44.32%
# Validation loss decreased (2.177507 --> 2.171470). Saving model ...
# Checkpoint saved to Google Drive at epoch 60
# Epoch 61/150 | Train Loss: 1.9422, Train Acc: 47.42% | Val Loss: 2.1564, Val Acc: 43.74%
# Validation loss decreased (2.171470 --> 2.156442). Saving model ...
# Checkpoint saved to Google Drive at epoch 61
# Epoch 62/150 | Train Loss: 1.9374, Train Acc: 47.60% | Val Loss: 2.1651, Val Acc: 43.80%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 62
# Epoch 63/150 | Train Loss: 1.9296, Train Acc: 47.61% | Val Loss: 2.2188, Val Acc: 43.74%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 63
# Epoch 64/150 | Train Loss: 1.9023, Train Acc: 48.35% | Val Loss: 2.1597, Val Acc: 44.31%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 64
# Epoch 65/150 | Train Loss: 1.8989, Train Acc: 48.50% | Val Loss: 2.1243, Val Acc: 44.62%
# Validation loss decreased (2.156442 --> 2.124348). Saving model ...
# Checkpoint saved to Google Drive at epoch 65
# Epoch 66/150 | Train Loss: 1.8842, Train Acc: 48.60% | Val Loss: 2.1041, Val Acc: 44.86%
# Validation loss decreased (2.124348 --> 2.104117). Saving model ...
# Checkpoint saved to Google Drive at epoch 66
# Epoch 67/150 | Train Loss: 1.8779, Train Acc: 48.96% | Val Loss: 2.1281, Val Acc: 44.86%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 67
# Epoch 68/150 | Train Loss: 1.8648, Train Acc: 49.12% | Val Loss: 2.1415, Val Acc: 44.61%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 68
# Epoch 69/150 | Train Loss: 1.8488, Train Acc: 49.51% | Val Loss: 2.1059, Val Acc: 44.79%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 69
# Epoch 70/150 | Train Loss: 1.8403, Train Acc: 49.76% | Val Loss: 2.1110, Val Acc: 45.25%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 70
# Epoch 71/150 | Train Loss: 1.8294, Train Acc: 50.16% | Val Loss: 2.1009, Val Acc: 45.31%
# Validation loss decreased (2.104117 --> 2.100950). Saving model ...
# Checkpoint saved to Google Drive at epoch 71
# Epoch 72/150 | Train Loss: 1.8153, Train Acc: 50.24% | Val Loss: 2.0873, Val Acc: 45.77%
# Validation loss decreased (2.100950 --> 2.087332). Saving model ...
# Checkpoint saved to Google Drive at epoch 72
# Epoch 73/150 | Train Loss: 1.8024, Train Acc: 50.53% | Val Loss: 2.0848, Val Acc: 45.86%
# Validation loss decreased (2.087332 --> 2.084834). Saving model ...
# Checkpoint saved to Google Drive at epoch 73
# Epoch 74/150 | Train Loss: 1.8029, Train Acc: 50.23% | Val Loss: 2.0429, Val Acc: 46.53%
# Validation loss decreased (2.084834 --> 2.042853). Saving model ...
# Checkpoint saved to Google Drive at epoch 74
# Epoch 75/150 | Train Loss: 1.7898, Train Acc: 50.78% | Val Loss: 2.0748, Val Acc: 46.23%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 75
# Epoch 76/150 | Train Loss: 1.7845, Train Acc: 50.67% | Val Loss: 2.0618, Val Acc: 46.10%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 76
# Epoch 77/150 | Train Loss: 1.7639, Train Acc: 51.53% | Val Loss: 2.0780, Val Acc: 45.56%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 77
# Epoch 78/150 | Train Loss: 1.7512, Train Acc: 51.46% | Val Loss: 2.0475, Val Acc: 46.21%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 78
# Epoch 79/150 | Train Loss: 1.7619, Train Acc: 51.23% | Val Loss: 2.0531, Val Acc: 46.42%
# EarlyStopping counter: 5 out of 10
# Checkpoint saved to Google Drive at epoch 79
# Epoch 80/150 | Train Loss: 1.7393, Train Acc: 51.78% | Val Loss: 2.0542, Val Acc: 45.85%
# EarlyStopping counter: 6 out of 10
# Checkpoint saved to Google Drive at epoch 80
# Epoch 81/150 | Train Loss: 1.7182, Train Acc: 52.15% | Val Loss: 2.0473, Val Acc: 46.36%
# EarlyStopping counter: 7 out of 10
# Checkpoint saved to Google Drive at epoch 81
# Epoch 82/150 | Train Loss: 1.7042, Train Acc: 53.00% | Val Loss: 2.0512, Val Acc: 46.72%
# EarlyStopping counter: 8 out of 10
# Checkpoint saved to Google Drive at epoch 82
# Epoch 83/150 | Train Loss: 1.7034, Train Acc: 52.68% | Val Loss: 2.0566, Val Acc: 45.81%
# EarlyStopping counter: 9 out of 10
# Checkpoint saved to Google Drive at epoch 83
# Epoch 84/150 | Train Loss: 1.6961, Train Acc: 52.70% | Val Loss: 2.0375, Val Acc: 46.88%
# Validation loss decreased (2.042853 --> 2.037524). Saving model ...
# Checkpoint saved to Google Drive at epoch 84
# Epoch 85/150 | Train Loss: 1.6868, Train Acc: 53.19% | Val Loss: 2.0202, Val Acc: 47.24%
# Validation loss decreased (2.037524 --> 2.020171). Saving model ...
# Checkpoint saved to Google Drive at epoch 85
# Epoch 86/150 | Train Loss: 1.6647, Train Acc: 53.63% | Val Loss: 2.0290, Val Acc: 46.73%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 86
# Epoch 87/150 | Train Loss: 1.6672, Train Acc: 53.47% | Val Loss: 2.0182, Val Acc: 47.04%
# Validation loss decreased (2.020171 --> 2.018229). Saving model ...
# Checkpoint saved to Google Drive at epoch 87
# Epoch 88/150 | Train Loss: 1.6569, Train Acc: 53.80% | Val Loss: 1.9861, Val Acc: 47.84%
# Validation loss decreased (2.018229 --> 1.986097). Saving model ...
# Checkpoint saved to Google Drive at epoch 88
# Epoch 89/150 | Train Loss: 1.6464, Train Acc: 54.41% | Val Loss: 2.0111, Val Acc: 47.88%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 89
# Epoch 90/150 | Train Loss: 1.6318, Train Acc: 54.09% | Val Loss: 2.0161, Val Acc: 47.39%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 90
# Epoch 91/150 | Train Loss: 1.6321, Train Acc: 54.40% | Val Loss: 1.9974, Val Acc: 47.59%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 91
# Epoch 92/150 | Train Loss: 1.6207, Train Acc: 54.46% | Val Loss: 1.9920, Val Acc: 47.77%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 92
# Epoch 93/150 | Train Loss: 1.5954, Train Acc: 55.42% | Val Loss: 2.0140, Val Acc: 47.92%
# EarlyStopping counter: 5 out of 10
# Checkpoint saved to Google Drive at epoch 93
# Epoch 94/150 | Train Loss: 1.5996, Train Acc: 55.22% | Val Loss: 1.9971, Val Acc: 47.69%
# EarlyStopping counter: 6 out of 10
# Checkpoint saved to Google Drive at epoch 94
# Epoch 95/150 | Train Loss: 1.5730, Train Acc: 55.90% | Val Loss: 1.9818, Val Acc: 47.97%
# Validation loss decreased (1.986097 --> 1.981803). Saving model ...
# Checkpoint saved to Google Drive at epoch 95
# Epoch 96/150 | Train Loss: 1.5803, Train Acc: 55.63% | Val Loss: 1.9854, Val Acc: 48.12%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 96
# Epoch 97/150 | Train Loss: 1.5753, Train Acc: 55.78% | Val Loss: 1.9501, Val Acc: 49.19%
# Validation loss decreased (1.981803 --> 1.950070). Saving model ...
# Checkpoint saved to Google Drive at epoch 97
# Epoch 98/150 | Train Loss: 1.5695, Train Acc: 55.95% | Val Loss: 1.9870, Val Acc: 48.36%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 98
# Epoch 99/150 | Train Loss: 1.5580, Train Acc: 56.02% | Val Loss: 1.9710, Val Acc: 48.42%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 99
# Epoch 100/150 | Train Loss: 1.5363, Train Acc: 56.53% | Val Loss: 1.9665, Val Acc: 48.58%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 100
# Epoch 101/150 | Train Loss: 1.5350, Train Acc: 56.76% | Val Loss: 1.9734, Val Acc: 48.49%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 101
# Epoch 102/150 | Train Loss: 1.5262, Train Acc: 56.70% | Val Loss: 1.9618, Val Acc: 48.67%
# EarlyStopping counter: 5 out of 10
# Checkpoint saved to Google Drive at epoch 102
# Epoch 103/150 | Train Loss: 1.5143, Train Acc: 56.84% | Val Loss: 1.9486, Val Acc: 48.55%
# Validation loss decreased (1.950070 --> 1.948599). Saving model ...
# Checkpoint saved to Google Drive at epoch 103
# Epoch 104/150 | Train Loss: 1.5065, Train Acc: 57.38% | Val Loss: 1.9440, Val Acc: 49.05%
# Validation loss decreased (1.948599 --> 1.944007). Saving model ...
# Checkpoint saved to Google Drive at epoch 104
# Epoch 105/150 | Train Loss: 1.5048, Train Acc: 57.21% | Val Loss: 1.9552, Val Acc: 49.42%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 105
# Epoch 106/150 | Train Loss: 1.4832, Train Acc: 58.10% | Val Loss: 1.9429, Val Acc: 49.25%
# Validation loss decreased (1.944007 --> 1.942872). Saving model ...
# Checkpoint saved to Google Drive at epoch 106
# Epoch 107/150 | Train Loss: 1.4966, Train Acc: 57.76% | Val Loss: 1.9335, Val Acc: 49.17%
# Validation loss decreased (1.942872 --> 1.933455). Saving model ...
# Checkpoint saved to Google Drive at epoch 107
# Epoch 108/150 | Train Loss: 1.4758, Train Acc: 58.13% | Val Loss: 1.9389, Val Acc: 49.88%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 108
# Epoch 109/150 | Train Loss: 1.4706, Train Acc: 57.78% | Val Loss: 1.9410, Val Acc: 49.61%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 109
# Epoch 110/150 | Train Loss: 1.4643, Train Acc: 58.20% | Val Loss: 1.9330, Val Acc: 49.66%
# Validation loss decreased (1.933455 --> 1.932982). Saving model ...
# Checkpoint saved to Google Drive at epoch 110
# Epoch 111/150 | Train Loss: 1.4447, Train Acc: 58.53% | Val Loss: 1.9273, Val Acc: 49.62%
# Validation loss decreased (1.932982 --> 1.927333). Saving model ...
# Checkpoint saved to Google Drive at epoch 111
# Epoch 112/150 | Train Loss: 1.4623, Train Acc: 58.17% | Val Loss: 1.9386, Val Acc: 49.25%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 112
# Epoch 113/150 | Train Loss: 1.4583, Train Acc: 58.30% | Val Loss: 1.9283, Val Acc: 49.76%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 113
# Epoch 114/150 | Train Loss: 1.4318, Train Acc: 58.98% | Val Loss: 1.9029, Val Acc: 49.76%
# Validation loss decreased (1.927333 --> 1.902939). Saving model ...
# Checkpoint saved to Google Drive at epoch 114
# Epoch 115/150 | Train Loss: 1.4307, Train Acc: 59.26% | Val Loss: 1.9253, Val Acc: 49.27%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 115
# Epoch 116/150 | Train Loss: 1.4369, Train Acc: 58.90% | Val Loss: 1.9056, Val Acc: 49.86%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 116
# Epoch 117/150 | Train Loss: 1.4224, Train Acc: 59.64% | Val Loss: 1.9112, Val Acc: 49.99%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 117
# Epoch 118/150 | Train Loss: 1.4054, Train Acc: 59.73% | Val Loss: 1.9025, Val Acc: 50.23%
# Validation loss decreased (1.902939 --> 1.902526). Saving model ...
# Checkpoint saved to Google Drive at epoch 118
# Epoch 119/150 | Train Loss: 1.4113, Train Acc: 59.35% | Val Loss: 1.9185, Val Acc: 50.23%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 119
# Epoch 120/150 | Train Loss: 1.4119, Train Acc: 59.46% | Val Loss: 1.9095, Val Acc: 49.64%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 120
# Epoch 121/150 | Train Loss: 1.4036, Train Acc: 59.87% | Val Loss: 1.9012, Val Acc: 49.87%
# Validation loss decreased (1.902526 --> 1.901159). Saving model ...
# Checkpoint saved to Google Drive at epoch 121
# Epoch 122/150 | Train Loss: 1.4009, Train Acc: 59.94% | Val Loss: 1.8949, Val Acc: 50.50%
# Validation loss decreased (1.901159 --> 1.894857). Saving model ...
# Checkpoint saved to Google Drive at epoch 122
# Epoch 123/150 | Train Loss: 1.3844, Train Acc: 60.46% | Val Loss: 1.8900, Val Acc: 50.33%
# Validation loss decreased (1.894857 --> 1.890046). Saving model ...
# Checkpoint saved to Google Drive at epoch 123
# Epoch 124/150 | Train Loss: 1.3797, Train Acc: 60.59% | Val Loss: 1.9110, Val Acc: 49.51%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 124
# Epoch 125/150 | Train Loss: 1.3770, Train Acc: 60.28% | Val Loss: 1.8913, Val Acc: 50.35%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 125
# Epoch 126/150 | Train Loss: 1.3846, Train Acc: 60.11% | Val Loss: 1.8984, Val Acc: 50.51%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 126
# Epoch 127/150 | Train Loss: 1.3781, Train Acc: 60.52% | Val Loss: 1.8952, Val Acc: 49.22%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 127
# Epoch 128/150 | Train Loss: 1.3755, Train Acc: 60.28% | Val Loss: 1.8988, Val Acc: 49.95%
# EarlyStopping counter: 5 out of 10
# Checkpoint saved to Google Drive at epoch 128
# Epoch 129/150 | Train Loss: 1.3661, Train Acc: 60.86% | Val Loss: 1.8995, Val Acc: 50.21%
# EarlyStopping counter: 6 out of 10
# Checkpoint saved to Google Drive at epoch 129
# Epoch 130/150 | Train Loss: 1.3521, Train Acc: 61.08% | Val Loss: 1.8883, Val Acc: 50.27%
# Validation loss decreased (1.890046 --> 1.888255). Saving model ...
# Checkpoint saved to Google Drive at epoch 130
# Epoch 131/150 | Train Loss: 1.3557, Train Acc: 60.90% | Val Loss: 1.9008, Val Acc: 50.15%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 131
# Epoch 132/150 | Train Loss: 1.3624, Train Acc: 60.91% | Val Loss: 1.8716, Val Acc: 50.35%
# Validation loss decreased (1.888255 --> 1.871601). Saving model ...
# Checkpoint saved to Google Drive at epoch 132
# Epoch 133/150 | Train Loss: 1.3622, Train Acc: 60.50% | Val Loss: 1.8730, Val Acc: 50.36%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 133
# Epoch 134/150 | Train Loss: 1.3449, Train Acc: 61.21% | Val Loss: 1.8768, Val Acc: 50.65%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 134
# Epoch 135/150 | Train Loss: 1.3523, Train Acc: 61.09% | Val Loss: 1.8969, Val Acc: 50.02%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 135
# Epoch 136/150 | Train Loss: 1.3575, Train Acc: 60.77% | Val Loss: 1.8680, Val Acc: 50.15%
# Validation loss decreased (1.871601 --> 1.868001). Saving model ...
# Checkpoint saved to Google Drive at epoch 136
# Epoch 137/150 | Train Loss: 1.3431, Train Acc: 61.20% | Val Loss: 1.8834, Val Acc: 51.11%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 137
# Epoch 138/150 | Train Loss: 1.3343, Train Acc: 61.33% | Val Loss: 1.8674, Val Acc: 50.94%
# Validation loss decreased (1.868001 --> 1.867408). Saving model ...
# Checkpoint saved to Google Drive at epoch 138
# Epoch 139/150 | Train Loss: 1.3448, Train Acc: 61.28% | Val Loss: 1.8796, Val Acc: 50.70%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 139
# Epoch 140/150 | Train Loss: 1.3475, Train Acc: 61.03% | Val Loss: 1.8842, Val Acc: 50.66%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 140
# Epoch 141/150 | Train Loss: 1.3323, Train Acc: 61.38% | Val Loss: 1.8736, Val Acc: 51.07%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 141
# Epoch 142/150 | Train Loss: 1.3317, Train Acc: 61.58% | Val Loss: 1.8747, Val Acc: 50.88%
# EarlyStopping counter: 4 out of 10
# Checkpoint saved to Google Drive at epoch 142
# Epoch 143/150 | Train Loss: 1.3259, Train Acc: 61.47% | Val Loss: 1.8788, Val Acc: 51.30%
# EarlyStopping counter: 5 out of 10
# Checkpoint saved to Google Drive at epoch 143
# Epoch 144/150 | Train Loss: 1.3344, Train Acc: 61.46% | Val Loss: 1.8894, Val Acc: 50.63%
# EarlyStopping counter: 6 out of 10
# Checkpoint saved to Google Drive at epoch 144
# Epoch 145/150 | Train Loss: 1.3287, Train Acc: 61.85% | Val Loss: 1.8878, Val Acc: 50.32%
# EarlyStopping counter: 7 out of 10
# Checkpoint saved to Google Drive at epoch 145
# Epoch 146/150 | Train Loss: 1.3282, Train Acc: 61.49% | Val Loss: 1.8905, Val Acc: 50.56%
# EarlyStopping counter: 8 out of 10
# Checkpoint saved to Google Drive at epoch 146
# Epoch 147/150 | Train Loss: 1.3329, Train Acc: 61.44% | Val Loss: 1.8644, Val Acc: 50.92%
# Validation loss decreased (1.867408 --> 1.864409). Saving model ...
# Checkpoint saved to Google Drive at epoch 147
# Epoch 148/150 | Train Loss: 1.3354, Train Acc: 61.48% | Val Loss: 1.8723, Val Acc: 50.53%
# EarlyStopping counter: 1 out of 10
# Checkpoint saved to Google Drive at epoch 148
# Epoch 149/150 | Train Loss: 1.3331, Train Acc: 61.35% | Val Loss: 1.8875, Val Acc: 50.06%
# EarlyStopping counter: 2 out of 10
# Checkpoint saved to Google Drive at epoch 149
# Epoch 150/150 | Train Loss: 1.3292, Train Acc: 61.56% | Val Loss: 1.8703, Val Acc: 50.34%
# EarlyStopping counter: 3 out of 10
# Checkpoint saved to Google Drive at epoch 150
# <ipython-input-8-2cb09d204108>:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/content/drive/MyDrive/Early2checkpoint.pt')
# Final Test Accuracy: 58.02%

# %% [markdown]
# # NEW OPTIMIZERS

# %%
# Train with NEW optimizer in this module
